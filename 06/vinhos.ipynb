# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('../dados/winequality-red.csv', delimiter=';')

# %%
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dados['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
plt.scatter(dados['alcohol'], dados['quality'])

# %%
plt.scatter(dados['alcohol'], dados['residual sugar'])

# %%
plt.scatter(dados['alcohol'], dados['quality'], c='r')
plt.scatter(dados['alcohol'], dados['residual sugar'], c='b')

# %%
dados.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dados.corr())

# %%
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X = dados.drop('quality', axis=1)
Y = dados['quality']

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
# !pip install scikit-learn
# Out:
# ...
#      |████████████████████████████████| 7.1MB 344kB/s eta 0:00:01
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
len(dados)
# Out:
# 1599

# %%
help(KNeighborsClassifier)
# Out:
# Help on class KNeighborsClassifier in module sklearn.neighbors._classification:
#
# class KNeighborsClassifier(sklearn.neighbors._base.NeighborsBase, sklearn.neighbors._base.KNeighborsMixin, sklearn.neighbors._base.SupervisedIntegerMixin, sklearn.base.ClassifierMixin)
#  |  Classifier implementing the k-nearest neighbors vote.
#  |
#  |  Read more in the :ref:`User Guide <classification>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_neighbors : int, optional (default = 5)
#  |      Number of neighbors to use by default for :meth:`kneighbors` queries.
#  |
#  |  weights : str or callable, optional (default = 'uniform')
#  |      weight function used in prediction.  Possible values:
#  |
#  |      - 'uniform' : uniform weights.  All points in each neighborhood
#  |        are weighted equally.
#  |      - 'distance' : weight points by the inverse of their distance.
#  |        in this case, closer neighbors of a query point will have a
# ...

# %%
modelo = KNeighborsClassifier(n_neighbors=5)

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(X, Y)

# %%
x_treino.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 627             8.8              0.60         0.29             2.2      0.098
# 651             9.8              0.88         0.25             2.5      0.104
# 807             8.2              0.28         0.40             2.4      0.052
# 256             9.4              0.34         0.37             2.2      0.075
# 1426            7.7              0.23         0.37             1.8      0.046
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 627                   5.0                  15.0  0.99880  3.36       0.49
# 651                  35.0                 155.0  1.00100  3.41       0.67
# 807                   4.0                  10.0  0.99356  3.33       0.70
# 256                   5.0                  13.0  0.99800  3.22       0.62
# 1426                 23.0                  60.0  0.99710  3.41       0.71
#
#       alcohol
# 627       9.1
# 651      11.2
# ...

# %%
y_treino.head()
# Out:
# 627     5
# 651     5
# 807     7
# 256     5
# 1426    6
# Name: quality, dtype: int64

# %%
modelo.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
modelo.score(x_teste, y_teste)
# Out:
# 0.5075

# %%
resultados = []
for k in range(3, 50, 2):
    modelo = KNeighborsClassifier(n_neighbors=k)
    modelo.fit(x_treino, y_treino)
    resultados.append(modelo.score(x_teste, y_teste))
plt.plot(range(3, 50, 2), resultados)

# %%
dados_branco = pd.read_csv('../dados/winequality-white.csv', delimiter=';')

# %%
len(dados_branco)
# Out:
# 4898

# %%
dados['tipo'] = 'tinto'
dados_branco['tipo'] = 'branco'

# %%
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality   tipo
# 0      9.4        5  tinto
# 1      9.8        5  tinto
# ...

# %%
dados_branco.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality    tipo
# 0      8.8        6  branco
# 1      9.5        6  branco
# ...

# %%
dados = dados.append(dados_branco, ignore_index=True)

# %%
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality   tipo
# 0      9.4        5  tinto
# 1      9.8        5  tinto
# ...

# %%
dados.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality    tipo
# ...

# %%
X = dados.drop('tipo', axis=1)
Y = dados['tipo']

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(X, Y, test_size=0.3)
modelo = KNeighborsClassifier()
modelo.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
modelo.score(x_teste, y_teste)
# Out:
# 0.9358974358974359

# %%
x_teste.iloc[0]
# Out:
# fixed acidity             6.800
# volatile acidity          0.210
# citric acid               0.360
# residual sugar           18.100
# chlorides                 0.046
# free sulfur dioxide      32.000
# total sulfur dioxide    133.000
# density                   1.000
# pH                        3.270
# sulphates                 0.480
# alcohol                   8.800
# quality                   5.000
# Name: 4096, dtype: float64

# %%
x_teste[:2]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4096            6.8              0.21         0.36            18.1      0.046
# 739             9.0              0.69         0.00             2.4      0.088
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4096                 32.0                 133.0    1.000  3.27       0.48
# 739                  19.0                  38.0    0.999  3.35       0.60
#
#       alcohol  quality
# 4096      8.8        5
# 739       9.3        5

# %%
modelo.predict(x_teste[:2])
# Out:
# array(['branco', 'tinto'], dtype=object)

# %%
y_teste[:2]
# Out:
# 4096    branco
# 739      tinto
# Name: tipo, dtype: object

# %%
df = pd.DataFrame(
    [[6.8,0.21,0.36,18.1,0.046,32.0,131.0,1.000,3.27,0.5,8.6,6]],
    columns=list(x_teste.columns)
)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8              0.21         0.36            18.1      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 32.0                 131.0      1.0  3.27        0.5
#
#    alcohol  quality
# 0      8.6        6

# %%
modelo.predict(df)
# Out:
# array(['branco'], dtype=object)
