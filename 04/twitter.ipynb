# %%
from tapioca_twitter import Twitter

api = Twitter(
    api_key='oFhSXrgXn5yrpBtoxhATVlh1Y',
    api_secret='Yazx70F1GWIeEvJRM2Q8ej5iW3QBThCBbndieVdYpz2WIfs5Dp',
    access_token='66525995-4llbHp3MoVtw1B2NuWvTegGGRv10GFGGYGRx8gWXK',
    access_token_secret='EHGjNRY6GhgwpCH9ZNJ9K6AqEXdfuZSUUJ9fYQbqIBJyc',
)

# %%
tweets = api.statuses_home_timeline().get()

# %%
tweets().data
# Out:
# [{'created_at': 'Sun Jan 12 17:09:17 +0000 2020',
#   'id': 1216406806949519360,
#   'id_str': '1216406806949519360',
#   'text': 'RT @iaraNaika: Churrasco na laje do Bonde do Falcão https://t.co/xeaEUes7lF',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'iaraNaika',
#      'name': 'Dora Marombeira',
#      'id': 1071529109593960449,
#      'id_str': '1071529109593960449',
#      'indices': [3, 13]}],
#    'urls': [],
#    'media': [{'id': 1216388866065797121,
#      'id_str': '1216388866065797121',
#      'indices': [52, 75],
#      'media_url': 'http://pbs.twimg.com/media/EOF7Op6XkAECUs8.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EOF7Op6XkAECUs8.jpg',
#      'url': 'https://t.co/xeaEUes7lF',
#      'display_url': 'pic.twitter.com/xeaEUes7lF',
#      'expanded_url': 'https://twitter.com/iaraNaika/status/1216388891424501765/photo/1',
#      'type': 'photo',
# ...

# %%
tweets = api.statuses_user_timeline().get(params={'screen_name': 'pycursos'})

# %%
len(tweets().data)
# Out:
# 20
